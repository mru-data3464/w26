# %% [markdown]
# # DATA 3464 Lab 6: practice for lab exam
# This exercise is graded pass/fail like other labs. Its main purpose is to practice for next week's lab exam to make sure the systems work and to give you a chance to test it out in a low stakes environment.
#
# Before you begin, **rename this notebook with your first name**.
#
# There are a number of cells with `TODO` items. Follow these steps, adding brief comments to explain your choices (e.g. "right skewed histogram, so log transform"). If you get stuck on a syntax error, add comments describing what you are trying to do.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# usually you only import what you want from scikit-learn, e.g.:
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# You may change or add to your imports as needed.
# Don't worry about keeping things too tidy - it's fine if you want to import additional modules in a later cell.

# %%
#TODO: Load the OKCupid data
df = pd.read_csv("okcupid.csv")

# %%
#TODO: Some basic exploration to learn about features, data types, distributions, etc
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   body_type    54650 non-null  object
#  2   diet         35551 non-null  object
#  3   drinks       56961 non-null  object
#  4   drugs        45866 non-null  object
#  5   education    53318 non-null  object
#  6   ethnicity    54266 non-null  object
#  7   height       59943 non-null  float64
#  8   income       59946 non-null  int64
#  9   job          51748 non-null  object
#  10  offspring    24385 non-null  object
#  11  orientation  59946 non-null  object
#  12  pets         40025 non-null  object
#  13  religion     39720 non-null  object
#  14  sex          59946 non-null  object
#  15  sign         48890 non-null  object
#  16  smokes       54434 non-null  object
#  17  speaks       59896 non-null  object
# ...

# %%
# see how many values in some of the categorical features
df["status"].value_counts() # pick status, easy category
df["drugs"].value_counts() # pick drugs to demo missing values
# Out:
# drugs
# never        37724
# sometimes     7732
# often          410
# Name: count, dtype: int64

# %%
train, test = train_test_split(df, test_size=0.2, random_state=42)

# %%
#TODO: Pick one of the categorical columns and build a processing pipeline for it.
# Your goal is to create a numeric feature appropriate for use with a linear model, making sure there are no missing values.
# Display your pipeline and keep the output rendered in your notebook.

# scale of never to often, natural ordering, use ordinal encoder
from sklearn.preprocessing import OrdinalEncoder
# pass categories in logical order
# map unknown values to -1 to keep range of values reasonable
drug_enc = OrdinalEncoder(
    categories=[["never", "sometimes", "often"]],
    handle_unknown="use_encoded_value", 
    unknown_value=-1
)

drug_enc
# Out:
# OrdinalEncoder(categories=[['never', 'sometimes', 'often']],
#                handle_unknown='use_encoded_value', unknown_value=-1)

# %%
#TODO: Fit your pipeline and transform the target feature. Print out the result to make sure it's working
from sklearn.compose import make_column_transformer
# tried to select column, can't remember syntax
# Too many double brackets!!
drugs = drug_enc.fit_transform(train[["drugs"]])
# pipeline = make_column_transformer(
#     (drug_enc, ["drugs"]),
# )

drugs = drug_enc.fit_transform(train[["drugs"]])

for d, de in zip(train["drugs"], drugs):
    print(d, de)
# Out:
# never [0.]
# nan [-1.]
# never [0.]
# sometimes [1.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# nan [-1.]
# never [0.]
# nan [-1.]
# nan [-1.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# nan [-1.]
# never [0.]
# nan [-1.]
# sometimes [1.]
# never [0.]
# nan [-1.]
# nan [-1.]
# never [0.]
# sometimes [1.]
# never [0.]
# nan [-1.]
# never [0.]
# sometimes [1.]
# never [0.]
# never [0.]
# nan [-1.]
# nan [-1.]
# never [0.]
# never [0.]
# sometimes [1.]
# never [0.]
# never [0.]
# nan [-1.]
# nan [-1.]
# never [0.]
# nan [-1.]
# nan [-1.]
# never [0.]
# sometimes [1.]
# sometimes [1.]
# nan [-1.]
# nan [-1.]
# never [0.]
# nan [-1.]
# sometimes [1.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# nan [-1.]
# nan [-1.]
# nan [-1.]
# nan [-1.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# never [0.]
# sometimes [1.]
# ...

# %% [markdown]
# When you have finished, **make sure your notebook is renamed with your first name** and copy it to the submit drive located at `I:\Labs\CompSci\Submit\3464`.  You are not able to make changes to files in the submit folder. If you want to make a change, you can create a new version (just add a number, e.g. `name_v2.ipynb`) and copy that one as well.
